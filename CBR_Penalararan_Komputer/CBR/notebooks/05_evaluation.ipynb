# %%
import os
print(os.getcwd())
# Out:
# d:\TUGAS SMT 6\PENALARAN KOMPUTER\TUGAS AKHIR UAS\CODE\Penalaran_Komputer\CBR_Penalararan_Komputer(8)\CBR\notebooks

# %%
# %cd ..
# Out:
# d:\TUGAS SMT 6\PENALARAN KOMPUTER\TUGAS AKHIR UAS\CODE\Penalaran_Komputer\CBR_Penalararan_Komputer(8)\CBR
# d:\TUGAS SMT 6\PENALARAN KOMPUTER\TUGAS AKHIR UAS\CODE\Penalaran_Komputer\CBR_Penalararan_Komputer(8)\CBR\notebooks\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from lime.lime_text import LimeTextExplainer
from tqdm import tqdm
import re
from nltk.tokenize import word_tokenize
import nltk

# Setup environment
def setup_environment():
    nltk.download('punkt', quiet=True)
    os.makedirs('data/eval', exist_ok=True)
    sns.set(style='whitegrid')

# Preprocess text (consistent with training)
def preprocess_text(text: str) -> str:
    try:
        text = str(text).lower()
        text = re.sub(r'\b(?:putusan|nomor|tahun|pengadilan|hakim)\b', '', text)
        text = re.sub(r'uu\s+no', 'undang-undang nomor', text)
        text = re.sub(r'pasal\s+\d+', 'pasal', text)
        text = re.sub(r'[^\w\s]', ' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return ' '.join(word_tokenize(text)) if text else 'empty'
    except Exception as e:
        print(f"Error preprocessing text: {e}")
        return 'empty'

# Load data
def load_data():
    try:
        with open('data/eval/queries.json', 'r', encoding='utf-8') as f:
            queries = json.load(f)
        ground_truth = {item['case_id']: item.get('solution', '') for item in queries}

        logreg_df = pd.read_csv('data/results/logreg_predictions.csv')
        svm_df = pd.read_csv('data/results/svm_predictions.csv')
        indobert_df = pd.read_csv('data/results/indobert_predictions.csv')

        cases_df = pd.read_csv('data/processed/cases.csv')
        texts = cases_df.set_index('case_id')['ringkasan_fakta'].to_dict()

        return queries, ground_truth, logreg_df, svm_df, indobert_df, texts
    except Exception as e:
        print(f"Error loading data: {e}")
        raise

# Evaluate retrieval (Accuracy@k and MRR)
def eval_retrieval(df, ground_truth, k=5):
    correct = 0
    reciprocal_ranks = []
    for _, row in df.iterrows():
        query_id = row['query_id']
        top_ids = row['top_5_case_ids'].split(', ')
        if query_id in top_ids:
            correct += 1
            rank = top_ids.index(query_id) + 1
            reciprocal_ranks.append(1.0 / rank)
        else:
            reciprocal_ranks.append(0.0)
    
    accuracy_at_k = correct / len(df) if len(df) > 0 else 0.0
    mrr = np.mean(reciprocal_ranks) if reciprocal_ranks else 0.0
    
    return {
        'accuracy_at_k': accuracy_at_k,
        'mrr': mrr
    }

# Evaluate prediction (Accuracy, Precision, Recall, F1-score)
def eval_prediction(df, ground_truth):
    y_true = []
    y_pred = []
    for _, row in df.iterrows():
        query_id = row['query_id']
        true_solution = ground_truth.get(query_id, '')
        pred_solution = row['predicted_solution']
        if true_solution and true_solution != '':
            y_true.append(true_solution)
            y_pred.append(pred_solution)

    try:
        accuracy = accuracy_score(y_true, y_pred)
        precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
        recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
        f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    except Exception as e:
        print(f"Error calculating prediction metrics: {e}")
        return {'accuracy': 0, 'precision': 0, 'recall': 0, 'f1_score': 0}

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }

# Generate and display confusion matrix
def display_confusion_matrix(df, ground_truth, model_name):
    y_true = []
    y_pred = []
    for _, row in df.iterrows():
        query_id = row['query_id']
        true_solution = ground_truth.get(query_id, '')
        pred_solution = row['predicted_solution']
        if true_solution and true_solution != '':
            y_true.append(true_solution)
            y_pred.append(pred_solution)
    
    try:
        cm = confusion_matrix(y_true, y_pred)
        labels = sorted(set(y_true + y_pred))
        cm_df = pd.DataFrame(cm, index=labels, columns=labels)
        
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
        plt.title(f'Confusion Matrix for {model_name}')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"Error generating confusion matrix for {model_name}: {e}")

# LIME error analysis (all errors)
def lime_error_analysis(df, texts, ground_truth, model_name):
    explainer = LimeTextExplainer(class_names=['Negative', 'Positive'])
    vectorizer = TfidfVectorizer(max_features=4000)
    sample_texts = [t for t in texts.values() if t]
    if not sample_texts:
        print(f"No valid texts for LIME analysis in {model_name}")
        return []
    
    vectorizer.fit([preprocess_text(t) for t in sample_texts])

    def classifier_fn(texts):
        text_vecs = vectorizer.transform([preprocess_text(t) for t in texts])
        scores = np.random.rand(len(texts), 2)  # Mock classifier
        return scores / scores.sum(axis=1, keepdims=True)

    errors = []
    for _, row in df.iterrows():
        query_id = row['query_id']
        pred = row['predicted_solution']
        true = ground_truth.get(query_id, '')
        if true and pred != true:
            text = texts.get(query_id, '')
            if text:
                try:
                    exp = explainer.explain_instance(preprocess_text(text), classifier_fn, num_features=10)
                    errors.append({
                        'query_id': query_id,
                        'true_solution': true,
                        'predicted_solution': pred,
                        'lime_weights': exp.as_list()
                    })
                except Exception as e:
                    print(f"Error in LIME analysis for query {query_id}: {e}")
    return errors

# Visualize metrics
def visualize_metrics(retrieval_metrics, prediction_metrics):
    try:
        retrieval_df = pd.DataFrame(retrieval_metrics).T[['accuracy_at_k', 'mrr']]
        prediction_df = pd.DataFrame(prediction_metrics).T[['accuracy', 'precision', 'recall', 'f1_score']]
        metrics_df = pd.concat([retrieval_df, prediction_df], axis=1)
        
        plt.figure(figsize=(15, 6))
        metrics_df.plot(kind='bar')
        plt.title('Retrieval and Prediction Metrics by Model')
        plt.ylabel('Score')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig('data/eval/performance_bar_chart.png')
        plt.show()
    except Exception as e:
        print(f"Error visualizing metrics: {e}")

# Main evaluation function
def main():
    setup_environment()
    queries, ground_truth, logreg_df, svm_df, indobert_df, texts = load_data()

    # Evaluate retrieval
    retrieval_metrics = {
        'Logistic Regression': eval_retrieval(logreg_df, ground_truth),
        'SVM': eval_retrieval(svm_df, ground_truth),
        'Indo-BERT': eval_retrieval(indobert_df, ground_truth)
    }

    # Evaluate prediction
    prediction_metrics = {
        'Logistic Regression': eval_prediction(logreg_df, ground_truth),
        'SVM': eval_prediction(svm_df, ground_truth),
        'Indo-BERT': eval_prediction(indobert_df, ground_truth)
    }

    # Save retrieval metrics
    try:
        retrieval_df = pd.DataFrame(retrieval_metrics).T
        retrieval_df.to_csv('data/eval/retrieval.csv')
        print("✅ Saved retrieval metrics to data/eval/retrieval.csv")
    except Exception as e:
        print(f"Error saving retrieval metrics: {e}")

    # Save prediction metrics
    try:
        prediction_df = pd.DataFrame(prediction_metrics).T
        prediction_df.to_csv('data/eval/predictions.csv')
        print("✅ Saved prediction metrics to data/eval/predictions.csv")
    except Exception as e:
        print(f"Error saving prediction metrics: {e}")

    # Display confusion matrices
    print("\nConfusion Matrices:")
    for model_name, df in [('Logistic Regression', logreg_df), ('SVM', svm_df), ('Indo-BERT', indobert_df)]:
        display_confusion_matrix(df, ground_truth, model_name)

    # Classification reports
    print("\nClassification Reports:")
    for model_name, df in [('Logistic Regression', logreg_df), ('SVM', svm_df), ('Indo-BERT', indobert_df)]:
        y_true = [ground_truth.get(row['query_id'], '') for _, row in df.iterrows() if ground_truth.get(row['query_id'], '')]
        y_pred = [row['predicted_solution'] for _, row in df.iterrows() if ground_truth.get(row['query_id'], '')]
        print(f"\n{model_name}:")
        try:
            print(classification_report(y_true, y_pred, zero_division=0))
        except Exception as e:
            print(f"Error generating classification report for {model_name}: {e}")

    # Visualize metrics
    visualize_metrics(retrieval_metrics, prediction_metrics)

    # Error analysis with LIME (all errors)
    print("\nError Analysis with LIME:")
    for model_name, df in [('Logistic Regression', logreg_df), ('SVM', svm_df), ('Indo-BERT', indobert_df)]:
        print(f"\n{model_name} Errors:")
        errors = lime_error_analysis(df, texts, ground_truth, model_name)
        if not errors:
            print("No errors found or no valid texts for analysis.")
        for error in errors:
            print(f"Query ID: {error['query_id']}")
            print(f"True Solution: {error['true_solution']}")
            print(f"Predicted Solution: {error['predicted_solution']}")
            print("LIME Weights:")
            for feature, weight in error['lime_weights']:
                print(f"  {feature}: {weight:.4f}")
            print()

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# ✅ Saved retrieval metrics to data/eval/retrieval_metrics.csv
# ✅ Saved prediction metrics to data/eval/prediction_metrics.csv
#
# Confusion Matrices:
# Classification Reports:
#
# Logistic Regression:
#                        precision    recall  f1-score   support
#
# Permohonan Dikabulkan       0.54      0.71      0.61        21
#    Permohonan Ditolak       0.60      0.41      0.49        22
#
#              accuracy                           0.56        43
#             macro avg       0.57      0.56      0.55        43
#          weighted avg       0.57      0.56      0.55        43
#
#
# SVM:
#                        precision    recall  f1-score   support
#
# Permohonan Dikabulkan       0.58      0.71      0.64        21
#    Permohonan Ditolak       0.65      0.50      0.56        22
#
#              accuracy                           0.60        43
#             macro avg       0.61      0.61      0.60        43
#          weighted avg       0.61      0.60      0.60        43
#
#
# Indo-BERT:
#                        precision    recall  f1-score   support
#
# Permohonan Dikabulkan       0.56      0.71      0.62        21
#    Permohonan Ditolak       0.62      0.45      0.53        22
#
#              accuracy                           0.58        43
#             macro avg       0.59      0.58      0.58        43
#          weighted avg       0.59      0.58      0.57        43
# Error Analysis with LIME:
#
# Logistic Regression Errors:
# Query ID: case_001
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   di: 0.0268
#   distrik: 0.0249
#   cara: -0.0230
#   dakwaan: -0.0207
#   berikut: 0.0200
#   surat: -0.0197
#   tempa: 0.0193
#   toilet: 0.0178
#   bulan: -0.0173
#   tanggal: -0.0168
#
# Query ID: case_003
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   mukhlas: 0.0237
#   atau: -0.0228
#   agus: -0.0211
#   hari: 0.0196
#   lain: -0.0192
#   terpisah: -0.0186
#   november: 0.0169
#   ke: 0.0159
#   ibrahim: -0.0158
#   dilakukan: 0.0154
#
# Query ID: case_004
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   dengan: 0.0246
#   salim: -0.0206
#   surat: 0.0196
#   one: -0.0191
#   dalam: 0.0170
#   moch: -0.0169
#   november: -0.0168
#   khoir: 0.0158
#   abdullah: -0.0155
#   abdul: 0.0150
#
# Query ID: case_012
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   tidaknya: 0.0279
#   hafid: 0.0200
#   penuntut: 0.0185
#   yang: 0.0179
#   gahtan: -0.0163
#   bulan: -0.0150
#   02: -0.0124
#   hari: -0.0123
#   tempat: -0.0110
#   jl: -0.0108
#
# Query ID: case_015
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   2008: 0.0319
#   dan: -0.0210
#   dihadapakan: -0.0206
#   melanggar: -0.0175
#   2: 0.0159
#   ayat: 0.0159
#   atas: -0.0140
#   2016: -0.0107
#   menimbang: -0.0078
#   terdakwa: -0.0067
#
# Query ID: case_017
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   ia: -0.0192
#   medan: 0.0187
#   2008: 0.0180
#   cilacap: 0.0178
#   kesatu: 0.0172
#   bertempat: -0.0155
#   lain: 0.0150
#   waktu: -0.0149
#   dengantahun: -0.0133
#   ketentuan: -0.0100
#
# Query ID: case_018
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   lain: -0.0253
#   bahwa: -0.0242
#   tepatnya: 0.0215
#   16: -0.0207
#   kongkong: -0.0206
#   negeri: 0.0154
#   tanggal: 0.0141
#   cekkeng: 0.0140
#   wita: 0.0107
#   tempat: 0.0083
#
# Query ID: case_020
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   gunawan: -0.0237
#   di: 0.0222
#   tidaknya: -0.0203
#   dakwaan: -0.0195
#   komplektamora: -0.0184
#   silalahi: -0.0176
#   negeri: 0.0157
#   2020: 0.0125
#   berdasarkan: 0.0104
#   tempat: 0.0103
#
# Query ID: case_030
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   kolaka: -0.0263
#   dengan: 0.0261
#   masih: 0.0247
#   kec: 0.0221
#   termasuk: -0.0205
#   7: 0.0177
#   sebagaimana: -0.0165
#   memanen: 0.0160
#   dilakukan: -0.0138
#   bulan: -0.0130
#
# Query ID: case_041
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   rabutanggal: 0.0311
#   sebagai: -0.0232
#   06: 0.0230
#   julianto: -0.0215
#   bin: 0.0194
#   berikut: -0.0190
#   saleh: 0.0182
#   dibidang: -0.0181
#   bahwa: -0.0167
#   dilakukan: -0.0164
#
# Query ID: case_042
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   peda: -0.0228
#   kabupaten: 0.0202
#   kel: -0.0199
#   budidarma: -0.0194
#   hari: 0.0190
#   berdasarkan: 0.0189
#   bahwa: 0.0188
#   cokro: 0.0179
#   ketut: -0.0161
#   daerah: -0.0122
#
# Query ID: case_051
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   terdakwa: -0.0235
#   primair: 0.0227
#   berdasarkan: -0.0161
#   penuntutumum: -0.0125
#   menimbang: -0.0123
#   bahwa: -0.0110
#   sebagai: 0.0103
#   dari: 0.0094
#   diajukan: -0.0067
#   dakwaan: 0.0053
#
# Query ID: case_052
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   yang: 0.0202
#   namun: 0.0189
#   kurun: 0.0179
#   minggu: -0.0157
#   berikut: -0.0130
#   daerah: -0.0130
#   masihtermasuk: -0.0115
#   berdasarkan: -0.0109
#   didakwa: -0.0103
#   denganhuston: -0.0090
#
# Query ID: case_057
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   setidak: 0.0291
#   ditempat: 0.0278
#   angka: -0.0274
#   termasuk: -0.0273
#   menunjukkanrasa: 0.0205
#   1: -0.0186
#   kepada: -0.0148
#   00: -0.0131
#   benci: -0.0106
#   sekira: -0.0094
#
# Query ID: case_058
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   tanggal: -0.0237
#   kuhap: -0.0227
#   pada: 0.0160
#   negeri: 0.0147
#   berdiam: 0.0124
#   murung: 0.0089
#   dakwaan: 0.0089
#   bin: 0.0087
#   hukumnya: 0.0071
#   atausetidak: 0.0066
#
# Query ID: case_060
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   effendy: -0.0293
#   bogor: -0.0243
#   camat: -0.0242
#   kuhap: 0.0215
#   net: 0.0167
#   tanggal: 0.0166
#   pasal: 0.0157
#   pertama: 0.0150
#   pada: 0.0112
#   cikarang: 0.0103
#
# Query ID: case_064
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   dan: -0.0211
#   euh: 0.0179
#   sl: -0.0175
#   limbau: 0.0163
#   diingat: -0.0147
#   tanggal: 0.0132
#   2015: 0.0129
#   dapat: -0.0127
#   gorontalo: -0.0120
#   umum: 0.0116
#
# Query ID: case_066
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   atau: 0.0246
#   alternatif: -0.0219
#   informasi: 0.0184
#   kuhp: -0.0173
#   pidana: -0.0171
#   a: 0.0167
#   menimbang: 0.0158
#   2016: -0.0149
#   ayat: 0.0139
#   jo: -0.0132
#
# Query ID: case_067
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   cilacap: 0.0187
#   tahyan: 0.0175
#   umum: 0.0171
#   dalam: 0.0158
#   jetis: -0.0155
#   pasal: -0.0148
#   tanggal: -0.0141
#   ayat: 0.0140
#   006: -0.0135
#   di: -0.0126
#
#
# SVM Errors:
# Query ID: case_001
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   dinas: 0.0262
#   negeri: -0.0238
#   masih: -0.0225
#   sitompul: 0.0207
#   yang: 0.0189
#   menyebarluaskan: 0.0179
#   penuntut: -0.0166
#   apt: -0.0165
#   termasuk: -0.0151
#   palangan: -0.0143
#
# Query ID: case_004
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   terpisah: -0.0311
#   abdulloh: 0.0274
#   zaidon: 0.0268
#   faisal: -0.0265
#   tanggal: -0.0260
#   lain: -0.0239
#   afif: 0.0206
#   muhlas: 0.0194
#   glen: -0.0192
#   abdullah: 0.0172
#
# Query ID: case_012
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   lintas: -0.0237
#   h: 0.0224
#   bertempat: 0.0187
#   dalam: -0.0185
#   2020: -0.0178
#   oktober: 0.0171
#   bahwa: -0.0156
#   jumat: -0.0154
#   telah: 0.0139
#   didakwa: 0.0134
#
# Query ID: case_013
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   bahwa: -0.0244
#   6: -0.0238
#   82: -0.0217
#   clarissa: -0.0208
#   belumtertangkap: 0.0173
#   failosufiahmad: 0.0163
#   rw: 0.0156
#   di: 0.0140
#   penjaringan: 0.0125
#   dengan: 0.0122
#
# Query ID: case_015
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   setiap: -0.0248
#   terdakwa: -0.0209
#   unsur: -0.0180
#   11: -0.0171
#   2016: 0.0152
#   berikut: 0.0135
#   pasal: 0.0113
#   dari: 0.0106
#   yang: 0.0098
#   tentang: 0.0075
#
# Query ID: case_018
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   kongkong: 0.0230
#   yangberwenang: -0.0203
#   2020: 0.0189
#   jl: -0.0174
#   bulan: -0.0157
#   kel: 0.0153
#   abd: -0.0139
#   terdakwa: 0.0136
#   bulukumba: 0.0113
#   harikamis: 0.0112
#
# Query ID: case_020
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   sebagai: 0.0241
#   mario: 0.0210
#   hukum: 0.0207
#   penuntutumum: -0.0183
#   bahwa: 0.0176
#   sama: -0.0157
#   yang: -0.0150
#   morawa: -0.0148
#   waktu: -0.0141
#   utara: -0.0140
#
# Query ID: case_030
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   2014: 0.0257
#   reg: 0.0252
#   bulan: 0.0214
#   kolaka: -0.0207
#   penuntut: -0.0176
#   desember: -0.0157
#   dalam: -0.0134
#   laloeha: -0.0121
#   lain: -0.0107
#   kec: -0.0102
#
# Query ID: case_041
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   rt: -0.0199
#   di: 0.0186
#   pisau: -0.0185
#   tdc: 0.0178
#   kalimantantengah: -0.0178
#   seolah: -0.0164
#   tersebut: 0.0164
#   terdakwa: -0.0161
#   informasielektronik: 0.0156
#   hari: 0.0137
#
# Query ID: case_046
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   pasal: -0.0237
#   primer: 0.0217
#   negerimanokwari: -0.0185
#   tempat: 0.0181
#   yang: -0.0170
#   penuntutumum: -0.0169
#   kuhap: -0.0159
#   2020: 0.0134
#   masihtermasuk: 0.0134
#   berikut: 0.0132
#
# Query ID: case_050
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   fatwa: -0.0270
#   sekira: -0.0252
#   2019: 0.0235
#   j7: 0.0216
#   menjabat: -0.0214
#   september: -0.0200
#   sudah: 0.0179
#   aplikasi: 0.0154
#   ataupunmendapat: -0.0141
#   erekles: 0.0130
#
# Query ID: case_051
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   diajukan: 0.0211
#   menimbang: 0.0132
#   ke: 0.0114
#   terdakwa: -0.0096
#   dari: -0.0080
#   dakwaan: -0.0072
#   paraf: -0.0058
#   penuntutumum: -0.0052
#   sebagai: -0.0046
#   berdasarkan: -0.0039
#
# Query ID: case_057
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   ditempat: -0.0269
#   umum: 0.0268
#   2019: -0.0259
#   kabupaten: -0.0259
#   dimaksud: 0.0199
#   menimbang: -0.0197
#   tidaknyapada: 0.0176
#   termasuk: 0.0173
#   gambar: 0.0157
#   pada: 0.0141
#
# Query ID: case_059
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   pokoknya: 0.0238
#   telah: -0.0232
#   3065: -0.0214
#   kemudian: 0.0206
#   001: -0.0181
#   sepeda: 0.0178
#   24: 0.0152
#   bekerja: -0.0152
#   polisi: -0.0150
#   memberikan: -0.0137
#
# Query ID: case_060
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   rutan: -0.0204
#   selasa: 0.0190
#   dalam: -0.0183
#   terdakwa: 0.0183
#   pertama: -0.0181
#   jawa: -0.0163
#   chandra: 0.0155
#   bekasi: -0.0153
#   penuntut: 0.0152
#   berwenang: 0.0150
#
# Query ID: case_066
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   kuhp: -0.0258
#   yaitu: 0.0240
#   2: 0.0223
#   melakukan: -0.0212
#   no: -0.0178
#   kesatu: 0.0150
#   terdakwa: 0.0143
#   11: -0.0129
#   menimbang: -0.0125
#   telah: -0.0112
#
# Query ID: case_067
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   agustus: -0.0206
#   dul: 0.0176
#   sidaurip: 0.0174
#   tanggal: -0.0154
#   jetis: 0.0151
#   setidak: -0.0142
#   raya: -0.0141
#   pada: -0.0120
#   tahyan: 0.0109
#   2020: -0.0103
#
#
# Indo-BERT Errors:
# Query ID: case_003
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   aliastauhid: 0.0280
#   sama: -0.0251
#   masing: -0.0228
#   dengan: -0.0218
#   yangsudah: -0.0196
#   fayyadh: 0.0167
#   als: -0.0166
#   didakwa: 0.0143
#   wahyu: 0.0141
#   abdurahman: 0.0119
#
# Query ID: case_009
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   bersalah: 0.0270
#   5: -0.0193
#   penjara: 0.0168
#   menuntut: -0.0163
#   sehingga: 0.0153
#   di: -0.0134
#   adalah: 0.0128
#   mempertimbangkan: 0.0125
#   akan: -0.0125
#   dijatuhi: -0.0109
#
# Query ID: case_010
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   nam: 0.0256
#   07: 0.0230
#   sebagai: -0.0217
#   dalam: -0.0209
#   perbuatan: 0.0205
#   tempat: 0.0185
#   hukumpengadilan: -0.0182
#   bahwa: -0.0177
#   sebagaiberikut: -0.0161
#   sarana: -0.0137
#
# Query ID: case_015
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   tentang: 0.0223
#   perubahan: -0.0219
#   dihadapakan: -0.0203
#   no: -0.0187
#   adalah: 0.0156
#   1: 0.0137
#   suratdakwaan: -0.0137
#   tunggal: 0.0101
#   orang2: 0.0101
#   dari: 0.0099
#
# Query ID: case_020
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   atau: -0.0339
#   berikut: -0.0265
#   suatu: -0.0234
#   limau: 0.0234
#   baik: -0.0230
#   negeri: 0.0228
#   berkas: 0.0227
#   sebagai: 0.0148
#   di: 0.0142
#   sama: 0.0113
#
# Query ID: case_030
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   laloeha: -0.0265
#   h: 0.0215
#   tawakkal: -0.0212
#   sengaja: 0.0187
#   surat: 0.0180
#   lain: 0.0166
#   pdm: 0.0162
#   desember: 0.0156
#   bertempat: -0.0156
#   sejak: -0.0131
#
# Query ID: case_038
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   jujur: 0.0279
#   didakwa: -0.0197
#   dan: 0.0178
#   juga: -0.0175
#   jalur: 0.0165
#   hanya: 0.0156
#   yangdibacakan: 0.0152
#   bahwa: -0.0143
#   mandiri: -0.0132
#   akademik: -0.0105
#
# Query ID: case_041
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   bangunan: -0.0276
#   indonesia: 0.0272
#   xl: -0.0259
#   hari: -0.0236
#   diajukan: 0.0226
#   seolah: -0.0213
#   sengaja: 0.0211
#   penuntutumum: 0.0153
#   dan: 0.0140
#   surat: 0.0138
#
# Query ID: case_042
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   jalan: -0.0294
#   orang: -0.0239
#   terdakwa: 0.0211
#   sengaja: -0.0200
#   januaritahun: -0.0198
#   penuntutumum: 0.0190
#   edi: 0.0172
#   klungkung: 0.0128
#   secaraterpisah: 0.0115
#   tanggal: 0.0114
#
# Query ID: case_043
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   30: 0.0217
#   hari: -0.0198
#   wita: -0.0191
#   klungkung: 0.0177
#   kel: -0.0172
#   25: -0.0170
#   made: -0.0156
#   tanggal: 0.0156
#   korban: 0.0147
#   galiran: 0.0140
#
# Query ID: case_044
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   kopet: 0.0243
#   januari2021: 0.0234
#   sekitar: -0.0231
#   ke: -0.0217
#   daerahhukum: -0.0200
#   penuntutumum: -0.0198
#   candraayustina: 0.0191
#   jalan: 0.0180
#   yang: 0.0180
#   waktu: -0.0170
#
# Query ID: case_045
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   sebagai: -0.0254
#   september: 0.0225
#   dua: 0.0224
#   dakwaan: 0.0209
#   maksud: -0.0200
#   mei: 0.0200
#   memiliki: -0.0188
#   pada: -0.0151
#   pdm: -0.0127
#   2: -0.0113
#
# Query ID: case_050
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   puji: 0.0241
#   menerima: 0.0240
#   dakwaan: 0.0223
#   berbicara: -0.0212
#   isi: 0.0201
#   tuhanallah: -0.0176
#   agung: -0.0168
#   diajukan: -0.0166
#   2: -0.0158
#   saksi: -0.0119
#
# Query ID: case_051
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   surat: 0.0146
#   primair: 0.0104
#   bahwa: -0.0096
#   sebagai: -0.0093
#   didakwa: -0.0075
#   diajukan: 0.0073
#   menimbang: 0.0069
#   persidangan: 0.0068
#   76: -0.0059
#   oleh: 0.0056
#
# Query ID: case_057
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   ke: -0.0254
#   didakwa: -0.0197
#   oleh: -0.0188
#   andipurnairawan: -0.0175
#   kepada: 0.0157
#   untuk: 0.0154
#   2019: 0.0135
#   jalan: 0.0109
#   dusun: 0.0103
#   berdasarkan: 0.0097
#
# Query ID: case_058
# True Solution: Permohonan Dikabulkan
# Predicted Solution: Permohonan Ditolak
# LIME Weights:
#   murung: 0.0309
#   rabu: 0.0216
#   tajudin: 0.0188
#   berikut: -0.0188
#   2020: 0.0186
#   hari: -0.0152
#   penuntutumum: -0.0145
#   oleh: -0.0138
#   shendy: -0.0130
#   30: -0.0126
#
# Query ID: case_060
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   sebagai: 0.0209
#   cikarang: -0.0194
#   tanggal: 0.0186
#   dalam: -0.0182
#   berdasarkan: 0.0167
#   didakwa: -0.0158
#   jalan: 0.0150
#   jawa: -0.0141
#   berada: -0.0141
#   masih: -0.0137
#
# Query ID: case_067
# True Solution: Permohonan Ditolak
# Predicted Solution: Permohonan Dikabulkan
# LIME Weights:
#   dul: -0.0226
#   surat: -0.0176
#   tertentu: -0.0167
#   006: 0.0166
#   pada: 0.0165
#   tanggal: 0.0164
#   cilacap: 0.0159
#   setidak: 0.0139
#   rt: -0.0136
#   berdasarkan: -0.0135
